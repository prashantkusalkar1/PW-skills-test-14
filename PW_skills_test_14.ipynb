# %% [markdown]
# Question 1: What is Anomaly Detection? Explain its types (point, contextual, and
# collective anomalies) with examples.

# %% [markdown]
# 1. Point Anomaly
#
# A point anomaly occurs when a single data point is very different from the rest of the dataset.
#
# 2. Contextual Anomaly
#
# A contextual anomaly occurs when a data point is abnormal in a specific context (such as time, season, or location) but may be normal in another context.
#
# 3. Collective Anomaly
#
# A collective anomaly occurs when a group of data points together behaves abnormally, even though individual points may appear normal.

# %% [markdown]
# Question 2: Compare Isolation Forest, DBSCAN, and Local Outlier Factor in terms of
# their approach and suitable use cases.

# %% [markdown]
# Question 2: Compare Isolation Forest, DBSCAN, and Local Outlier Factor in terms of their approach and suitable use cases.

# %% [markdown]
# 1. Isolation Forest
#
# Approach:
# Isolation Forest is a tree-based algorithm that isolates anomalies instead of profiling normal data.
#
# It randomly selects a feature and split value to divide the data.
#
# Anomalies are easier to isolate because they are rare and different, so they require fewer splits in the tree.
#
# 2. DBSCAN (Density-Based Spatial Clustering of Applications with Noise)
#
# Approach:
# DBSCAN is a density-based clustering algorithm that groups points in high-density regions and marks points in low-density areas as outliers (noise).
#
# 3. Local Outlier Factor (LOF)
#
# Approach:
# LOF is a density-based anomaly detection method that compares the local density of a point to the density of its neighbors.
#
# If a point has much lower density than its neighbors, it is considered an outlier.

# %% [markdown]
# Question 3: What are the key components of a Time Series? Explain each with one example.

# %% [markdown]
# 1. Trend
#
# Trend represents the long-term movement or direction in the data over time.
# It shows whether the data is increasing, decreasing, or remaining stable.
#
# 2. Seasonality
#
# Seasonality refers to regular patterns that repeat at fixed intervals, such as daily, weekly, monthly, or yearly.
#
# 3. Cyclical Component
#
# The cyclical component represents long-term fluctuations that occur over irregular periods, usually influenced by economic or business cycles.
#
# 4. Irregular (Random) Component
#
# The irregular component consists of unexpected or random variations in the data that cannot be predicted.

# %% [markdown]
# Question 4: Define Stationary in time series. How can you test and transform a
# non-stationary series into a stationary one?

# %% [markdown]
# Stationarity in Time Series
#
# A time series is called stationary when its statistical properties remain constant over time.
#
# Why Stationarity is Important
#
# Many time-series models such as ARIMA assume that the data is stationary.
# If the series is not stationary, the model may produce unreliable forecasts.
#
# 1. Visual Inspection
#
# Plot the time series and check for:
#
# Upward or downward trend
#
# Changing variance
#
# Seasonal patterns
#
# 2. Statistical Tests
# Augmented Dickey-Fuller (ADF) Test
#
# The ADF test is commonly used to check stationarity.

# %%
from statsmodels.tsa.stattools import adfuller

result = adfuller(time_series)
print("ADF Statistic:", result[0])
print("p-value:", result[1])

# %% [markdown]
# How to Transform a Non-Stationary Series into a Stationary One
# 1. Differencing
#
# Subtract the previous observation from the current observation.

# %%
data_diff = data.diff().dropna()

# %% [markdown]
# 2. Log Transformation
#
# Used to stabilize variance when data grows exponentially.
#
# Example:
#
# import numpy as np
# log_data = np.log(data)

# %% [markdown]
# 3. Moving Average / Smoothing
#
# Removes short-term fluctuations to highlight the trend.
#
# Example:
#
# data_ma = data.rolling(window=12).mean()

# %% [markdown]
# Question 5: Differentiate between AR, MA, ARIMA, SARIMA, and SARIMAX models in
# terms of structure and application.

# %% [markdown]
# 1. AR (AutoRegressive) Model
#
# Structure:
# The AR model predicts future values based on previous values of the time series.
#
# 2. MA (Moving Average) Model
#
# Structure:
# The MA model predicts values based on past forecast errors (residuals).
#
# 3. ARIMA (AutoRegressive Integrated Moving Average)
#
# Structure:
# ARIMA combines:
#
# AR (p) → autoregressive terms
#
# I (d) → differencing to make series stationary
#
# MA (q) → moving average terms
#
# 4. SARIMA (Seasonal ARIMA)
#
# Structure:
# SARIMA extends ARIMA by adding seasonal components
#
# (p,d,q) = non-seasonal components
#
# (P,D,Q) = seasonal components
#
# s = seasonal period (e.g., 12 for monthly data)
#
# 5. SARIMAX (Seasonal ARIMA with Exogenous Variables)
#
# Structure:
# SARIMAX extends SARIMA by including external variables (exogenous features).
#
# Example external variables:
#
# Weather
#
# Promotions
#
# Economic indicators
